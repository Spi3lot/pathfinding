# %%
import pandas as pd
import seaborn as sns

# %%
benchmark = pd.read_csv('flexible-benchmark.csv')
benchmark.insert(1, 'Path Present', benchmark['Path Length'] != 0, True)
benchmark.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Algorithm       4000 non-null   object
#  1   Path Present    4000 non-null   bool
#  2   Path Length     4000 non-null   int64
#  3   Duration (µs)   4000 non-null   float64
#  4   Average Degree  4000 non-null   float64
# dtypes: bool(1), float64(2), int64(1), object(1)
# memory usage: 129.0+ KB

# %%
benchmark_path = benchmark[benchmark['Path Present']]
benchmark_path.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2588 entries, 0 to 3997
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Algorithm       2588 non-null   object
#  1   Path Present    2588 non-null   bool
#  2   Path Length     2588 non-null   int64
#  3   Duration (µs)   2588 non-null   float64
#  4   Average Degree  2588 non-null   float64
# dtypes: bool(1), float64(2), int64(1), object(1)
# memory usage: 103.6+ KB

# %%
benchmark_nopath = benchmark[benchmark['Path Present'] == False]
benchmark_nopath.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1412 entries, 1 to 3999
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Algorithm       1412 non-null   object
#  1   Path Present    1412 non-null   bool
#  2   Path Length     1412 non-null   int64
#  3   Duration (µs)   1412 non-null   float64
#  4   Average Degree  1412 non-null   float64
# dtypes: bool(1), float64(2), int64(1), object(1)
# memory usage: 56.5+ KB

# %% [markdown]
# # Duration of algorithms where a path is present vs not present

# %%
sns.lineplot(benchmark, x='Algorithm', y='Duration (µs)', hue='Path Present', palette='colorblind')
# Out:
# <Axes: xlabel='Algorithm', ylabel='Duration (µs)'>

# %% [markdown]
# # Relationship between path length and duration

# %%
sns.lineplot(benchmark_path, x='Path Length', y='Duration (µs)', hue='Algorithm')
# Out:
# <Axes: xlabel='Path Length', ylabel='Duration (µs)'>

# %% [markdown]
# # Relationship between average degree and duration

# %%
sns.lineplot(benchmark_path, x='Average Degree', y='Duration (µs)', hue='Algorithm')
# Out:
# <Axes: xlabel='Average Degree', ylabel='Duration (µs)'>

# %% [markdown]
# # Relationship between path length and average degree

# %%
sns.lineplot(benchmark, x='Path Length', y='Average Degree')
# Out:
# <Axes: xlabel='Path Length', ylabel='Average Degree'>

# %%
sns.histplot(benchmark[benchmark['Duration (µs)'] < 50], x='Duration (µs)', hue='Algorithm', multiple='stack')
# Out:
# <Axes: xlabel='Duration (µs)', ylabel='Count'>

# %% [markdown]
# # Correlation Heatmap

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 benchmark.corr()
#
# File ~\.conda\envs\dsai\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\.conda\envs\dsai\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# File ~\.conda\envs\dsai\Lib\site-packages\pandas\core\internals\managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File ~\.conda\envs\dsai\Lib\site-packages\pandas\core\internals\managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: 'BidiBestFirstSearch'
