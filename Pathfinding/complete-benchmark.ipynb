# %%
import pandas as pd
import seaborn as sns

# %%
benchmark = pd.read_csv('complete-benchmark.csv')
benchmark.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Algorithm       4000 non-null   object
#  1   Path Length     4000 non-null   int64
#  2   Duration (µs)   4000 non-null   float64
#  3   Average Degree  4000 non-null   int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 125.1+ KB

# %% [markdown]
# # Duration of algorithms where a path is present vs not present

# %%
sns.barplot(benchmark, x='Algorithm', y='Duration (µs)')
# Out:
# <Axes: xlabel='Algorithm', ylabel='Duration (µs)'>

# %% [markdown]
# # Relationship between visit count and duration

# %%
sns.scatterplot(benchmark, x='Visited Vertices', y='Duration (µs)', hue='Algorithm')

# %% [markdown]
# # Relationship between path length and duration

# %%
sns.lineplot(benchmark, x='Path Length', y='Duration (µs)', hue='Algorithm')
# Out:
# <Axes: xlabel='Path Length', ylabel='Duration (µs)'>

# %% [markdown]
# # Distribution of durations for each algorithm

# %%
sns.histplot(benchmark[benchmark['Duration (µs)'] < 12000], x='Duration (µs)', hue='Algorithm')
# Out:
# <Axes: xlabel='Duration (µs)', ylabel='Count'>

# %% [markdown]
# # Correlation Heatmap

# %%
sns.heatmap(benchmark.drop(columns='Average Degree').corr(method='spearman', numeric_only=True), annot=True)
# Out:
# <Axes: >
